# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **JOBS API Implementation Using FLASK**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Objectives
#
# You will be executing this code  so that the client application **Collecting Jobs API**  will be accessing this code executing on the server

# %%
# !pip install flask
# Out:
# Collecting flask
#   Downloading Flask-2.0.3-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 8.3 MB/s  eta 0:00:01
# Requirement already satisfied: Werkzeug>=2.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from flask) (2.0.2)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: click>=7.1.2 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from flask) (8.0.3)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from flask) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from Jinja2>=3.0->flask) (2.0.1)
# Installing collected packages: itsdangerous, flask
# Successfully installed flask-2.0.3 itsdangerous-2.1.1

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: [https://www.kaggle.com/promptcloud/jobs-on-naukricom](https://www.kaggle.com/promptcloud/jobs-on-naukricom?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01) under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %%
# !wget  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json
# Out:
# --2022-03-09 16:30:31--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12878382 (12M) [application/json]
# Saving to: ‘jobs.json.2’
#
# jobs.json.2         100%[===================>]  12.28M  50.3MB/s    in 0.2s
#
# 2022-03-09 16:30:31 (50.3 MB/s) - ‘jobs.json.2’ saved [12878382/12878382]

# %%
import flask
from flask import request, jsonify
import requests
import re

def get_data(key,value,current):
    results = list()
    for rec in current:
        
        if rec[key].find(value) != -1:
            results.append(rec)
    return results

app = flask.Flask(__name__)

import json
data = None
with open('jobs.json',encoding='utf-8') as f:
    # returns JSON object as
    # a dictionary
    data = json.load(f)
    
    

@app.route('/', methods=['GET'])
def home():
    
    return '''<h1>Welcome to flask JOB search API</p>'''


@app.route('/data/all', methods=['GET'])
def api_all():
    return jsonify(data)


@app.route('/data', methods=['GET'])
def api_id():
    # Check if keys such as Job Title,KeySkills, Role Category and others  are provided as part of the URL.
    #  Assign the keys to the corresponding variables..
    # If no key is provided, display an error in the browser.
    res = None
    for req in request.args:
        
        if req == 'Job Title':
            key = 'Job Title'
        elif req == 'Job Experience Required' :
            key='Job Experience Required'
        elif req == 'Key Skills' :
            key='Key Skills'
            
        elif req == 'Role Category' :
            key='Role Category'
        elif req == 'Location' :
            key='Location'
        
        elif req == 'Functional Area' :
            key='Functional Area'
        
        elif req == 'Industry' :
            key='Industry'
        elif req == 'Role' :
            key='Role'
        elif req=="id":
             key="id"
        else:
            pass
    
        value = request.args[key]
        if (res==None):
            res = get_data(key,value,data)
        else:
            res = get_data(key,value,res)

    # Use the jsonify function from Flask to convert our list of
    # Python dictionaries to the JSON format.
    return jsonify(res)

app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Mar/2022 16:31:13] "GET /data HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:31:27] "GET /data HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:31:33] "GET /data HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:31:36] "GET /data HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:31:38] "GET /data?Key+Skills=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:31:48] "GET /data HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:31:50] "GET /data?Key+Skills=Python HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:34:20] "GET /data?Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:08] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:08] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:08] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:08] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:08] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:08] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:08] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:59] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:59] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:59] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:59] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:59] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:59] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:52:59] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:53:12] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:53:16] "GET /data?Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:53:25] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:53:25] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:53:25] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:53:25] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:53:25] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:53:25] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:53:25] "GET /data?Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:55:08] "GET /data?Key+Skills=Python&Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:55:08] "GET /data?Key+Skills=Python&Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:55:08] "GET /data?Key+Skills=Python&Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:55:08] "GET /data?Key+Skills=Python&Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:55:08] "GET /data?Key+Skills=Python&Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:55:08] "GET /data?Key+Skills=Python&Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 16:55:08] "GET /data?Key+Skills=Python&Location=Los+Angeles&Location=New+York&Location=San+Francisco&Location=Washington+DC&Location=Seattle&Location=Austin&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:03:18] "GET /data?Key+Skills=Python&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:03:18] "GET /data?Key+Skills=Python&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:03:18] "GET /data?Key+Skills=Python&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:03:18] "GET /data?Key+Skills=Python&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:03:18] "GET /data?Key+Skills=Python&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:03:19] "GET /data?Key+Skills=Python&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:03:19] "GET /data?Key+Skills=Python&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:18:57] "GET /data?Key+Skills=C&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:18:57] "GET /data?Key+Skills=C&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:18:57] "GET /data?Key+Skills=C&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:18:57] "GET /data?Key+Skills=C&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:18:57] "GET /data?Key+Skills=C&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:18:57] "GET /data?Key+Skills=C&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:18:57] "GET /data?Key+Skills=C&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:23:14] "GET /data?Key+Skills=C&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:23:14] "GET /data?Key+Skills=C&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:23:14] "GET /data?Key+Skills=C&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:23:14] "GET /data?Key+Skills=C&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:23:15] "GET /data?Key+Skills=C&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:23:15] "GET /data?Key+Skills=C&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:23:15] "GET /data?Key+Skills=C&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:20] "GET /data?Key+Skills=C&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:20] "GET /data?Key+Skills=C&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:20] "GET /data?Key+Skills=C&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:20] "GET /data?Key+Skills=C&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:20] "GET /data?Key+Skills=C&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:20] "GET /data?Key+Skills=C&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:20] "GET /data?Key+Skills=C&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:27] "GET /data?Key+Skills=C&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:27] "GET /data?Key+Skills=C&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:27] "GET /data?Key+Skills=C&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:27] "GET /data?Key+Skills=C&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:28] "GET /data?Key+Skills=C&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:28] "GET /data?Key+Skills=C&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:28] "GET /data?Key+Skills=C&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:38] "GET /data?Key+Skills=C&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:38] "GET /data?Key+Skills=C&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:38] "GET /data?Key+Skills=C&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:38] "GET /data?Key+Skills=C&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:38] "GET /data?Key+Skills=C&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:38] "GET /data?Key+Skills=C&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:24:38] "GET /data?Key+Skills=C&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:45] "GET /data?Key+Skills=C&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:45] "GET /data?Key+Skills=C&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:45] "GET /data?Key+Skills=C&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:45] "GET /data?Key+Skills=C&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:45] "GET /data?Key+Skills=C&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:45] "GET /data?Key+Skills=C&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%23&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%23&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%23&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%23&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%23&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%23&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%23&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%2B%2B&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%2B%2B&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%2B%2B&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%2B%2B&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%2B%2B&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%2B%2B&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=C%2B%2B&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Java&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Java&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Java&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Java&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Java&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Java&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Java&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=JavaScript&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=JavaScript&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=JavaScript&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=JavaScript&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=JavaScript&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=JavaScript&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=JavaScript&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Python&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Python&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Python&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Python&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Python&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Python&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Python&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Scala&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Scala&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Scala&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Scala&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Scala&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Scala&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Scala&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Oracle&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Oracle&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Oracle&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Oracle&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Oracle&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Oracle&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=Oracle&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=SQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=SQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=SQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=SQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=SQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=SQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=SQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=MySQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=MySQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=MySQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=MySQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:46] "GET /data?Key+Skills=MySQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=MySQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=MySQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=PostgreSQL&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=PostgreSQL&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=PostgreSQL&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=PostgreSQL&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=PostgreSQL&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=PostgreSQL&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=PostgreSQL&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=MongoDB&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=MongoDB&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=MongoDB&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=MongoDB&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=MongoDB&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=MongoDB&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:25:47] "GET /data?Key+Skills=MongoDB&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:17] "GET /data?Key+Skills=C&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%23&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%23&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%23&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%23&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%23&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%23&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%23&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%2B%2B&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%2B%2B&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%2B%2B&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%2B%2B&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%2B%2B&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%2B%2B&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=C%2B%2B&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Java&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Java&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Java&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Java&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Java&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Java&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Java&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=JavaScript&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=JavaScript&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=JavaScript&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=JavaScript&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=JavaScript&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=JavaScript&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=JavaScript&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Python&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Python&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Python&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Python&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Python&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Python&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Python&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Scala&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Scala&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Scala&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Scala&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Scala&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Scala&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Scala&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Oracle&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Oracle&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Oracle&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Oracle&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Oracle&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Oracle&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=Oracle&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=SQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:18] "GET /data?Key+Skills=SQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=SQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=SQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=SQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=SQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=SQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MySQL+Server&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MySQL+Server&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MySQL+Server&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MySQL+Server&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MySQL+Server&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MySQL+Server&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MySQL+Server&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=PostgreSQL&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=PostgreSQL&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=PostgreSQL&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=PostgreSQL&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=PostgreSQL&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=PostgreSQL&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=PostgreSQL&Location=Detroit HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MongoDB&Location=Los+Angeles HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MongoDB&Location=New+York HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MongoDB&Location=San+Francisco HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MongoDB&Location=Washington+DC HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MongoDB&Location=Seattle HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MongoDB&Location=Austin HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2022 17:30:19] "GET /data?Key+Skills=MongoDB&Location=Detroit HTTP/1.1" 200 -

# %% [markdown]
# ## Authors

# %% [markdown]
# Lakshmi Holla

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Malika Singla\
# Ayushi Jain

# %% [markdown]
# ## Changelog

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description      |
# | ----------------- | ------- | ------------- | ----------------------- |
# | 2022-01-03        | 0.1     | Lakshmi Holla | Created Initial Version |

# %% [markdown]
# Copyright © 2022 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
